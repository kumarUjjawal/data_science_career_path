# %% [markdown]
# ## Goodreads Data Analysis

# %%
import pandas as pd
df = pd.read_csv('ujjawal.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 31 columns):
# Book Id                       222 non-null int64
# Title                         222 non-null object
# Author                        222 non-null object
# Author l-f                    222 non-null object
# Additional Authors            54 non-null object
# ISBN                          222 non-null object
# ISBN13                        222 non-null object
# My Rating                     222 non-null int64
# Average Rating                222 non-null float64
# Publisher                     222 non-null object
# Binding                       222 non-null object
# Number of Pages               221 non-null float64
# Year Published                221 non-null float64
# Original Publication Year     221 non-null float64
# Date Read                     62 non-null object
# Date Added                    222 non-null object
# Bookshelves                   70 non-null object
# ...

# %%
df.describe()
# Out:
#             Book Id   My Rating  Average Rating  Number of Pages  \
# count  2.220000e+02  222.000000      222.000000       221.000000
# mean   1.558920e+07    1.373874        4.021577       336.832579
# std    1.474434e+07    2.141983        0.240290       196.200510
# min    6.670000e+02    0.000000        3.240000        11.000000
# 25%    9.331525e+04    0.000000        3.870000       208.000000
# 50%    1.345099e+07    0.000000        4.060000       305.000000
# 75%    2.869498e+07    4.000000        4.190000       405.000000
# max    4.477704e+07    5.000000        4.540000      1318.000000
#
#        Year Published  Original Publication Year  My Review  Spoiler  \
# count      221.000000                 221.000000        0.0      0.0
# mean      2009.013575                1948.927602        NaN      NaN
# std          9.473638                 304.462349        NaN      NaN
# min       1950.000000                -500.000000        NaN      NaN
# ...

# %%
df.drop(['Recommended By', 'Owned Copies', 'Original Purchase Date'],axis=1)
# Out:
#       Book Id                                              Title  \
# 0     6547258                    The Final Empire (Mistborn, #1)
# 1    34446112         Fragile Things: Short Fictions and Wonders
# 2     2913377  The Name of the Wind (The Kingkiller Chronicle...
# 3    35820369  The Rise and Fall of the Dinosaurs: A New Hist...
# 4    35133922                                           Educated
# 5     3428935                   The Warded Man (Demon Cycle, #1)
# 6       51964                  Old Man's War (Old Man's War, #1)
# 7        6288                                           The Road
# 8         667                                             Anthem
# 9       11297                                     Norwegian Wood
# 10   43702513                         To Be Taught, If Fortunate
# 11     321005                    True Names... and Other Dangers
# 12    7562764           The Quantum Thief (Jean le Flambeur, #1)
# ...

# %%
df.head()
# Out:
#     Book Id                                              Title  \
# 0   6547258                    The Final Empire (Mistborn, #1)
# 1  34446112         Fragile Things: Short Fictions and Wonders
# 2   2913377  The Name of the Wind (The Kingkiller Chronicle...
# 3  35820369  The Rise and Fall of the Dinosaurs: A New Hist...
# 4  35133922                                           Educated
#
#               Author          Author l-f Additional Authors           ISBN  \
# 0  Brandon Sanderson  Sanderson, Brandon                NaN  ="0575089911"
# 1        Neil Gaiman        Gaiman, Neil                NaN  ="0062699547"
# 2   Patrick Rothfuss   Rothfuss, Patrick                NaN  ="0575081406"
# 3   Stephen Brusatte   Brusatte, Stephen                NaN  ="0062490427"
# 4      Tara Westover      Westover, Tara                NaN  ="0399590501"
#
#              ISBN13  My Rating  Average Rating                  Publisher  \
# ...

# %%
data = df.copy()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-c8ad017eadea> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 plt.scatter(df)
#
# TypeError: scatter() missing 1 required positional argument: 'y'
