# %% [markdown]
# ## Data Wrangling

# %%
import pandas as pd

url = 'https://tinyurl.com/titanic-csv'

df = pd.read_csv(url)

# %%
df.head(5)
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %%
dataframe = pd.DataFrame()

dataframe['Name'] = ['Matt', 'Paige']
dataframe['Age'] = [32,30]
dataframe['Ninja'] = [True, False]

dataframe
# Out:
#     Name  Age  Ninja
# 0   Matt   32   True
# 1  Paige   30  False

# %%
new_member = pd.Series(['Nelson',31, False], index=['Name','Age','Ninja'])

dataframe.append(new_member, ignore_index=True)
# Out:
#      Name  Age  Ninja
# 0    Matt   32   True
# 1   Paige   30  False
# 2  Nelson   31  False

# %%
df.shape
# Out:
# (1313, 6)

# %%
df.describe()
# Out:
#               Age     Survived      SexCode
# count  756.000000  1313.000000  1313.000000
# mean    30.397989     0.342727     0.351866
# std     14.259049     0.474802     0.477734
# min      0.170000     0.000000     0.000000
# 25%     21.000000     0.000000     0.000000
# 50%     28.000000     0.000000     0.000000
# 75%     39.000000     1.000000     1.000000
# max     71.000000     1.000000     1.000000

# %%
df.iloc[1:4]
# Out:
#                                             Name PClass   Age     Sex  \
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.0    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
#
#    Survived  SexCode
# 1         0        1
# 2         0        0
# 3         0        1

# %%
df = df.set_index(df['Age'])

age_22 = df.loc[22]

# %%
age_22.head(5)
# Out:
#                             Name PClass   Age     Sex  Survived  SexCode
# Age
# 22.0  Bowerman, Miss Elsie Edith    1st  22.0  female         1        1
# 22.0  Frolicher, Miss Marguerite    1st  22.0  female         1        1
# 22.0        Gibson, Miss Dorothy    1st  22.0  female         1        1
# 22.0  Ostby, Miss Helen Raghnild    1st  22.0  female         1        1
# 22.0   Payne, Mr Vivian Ponsonby    1st  22.0    male         0        0

# %%
df = age_22.set_index(age_22['Sex'])

female = df.loc['female']

# %%
female
# Out:
#                                                      Name PClass   Age  \
# Sex
# female                         Bowerman, Miss Elsie Edith    1st  22.0
# female                         Frolicher, Miss Marguerite    1st  22.0
# female                               Gibson, Miss Dorothy    1st  22.0
# female                         Ostby, Miss Helen Raghnild    1st  22.0
# female                            Cook, Mrs Selena Rogers    2nd  22.0
# female       del Carlo, Mrs Sebastiano (Argenia Genovese)    2nd  22.0
# female               Karnes, Mrs J Frank (Claire Bennett)    2nd  22.0
# female                       LaRoche, Mrs Joseph (Juliet)    2nd  22.0
# female                                Connolly, Miss Kate    3rd  22.0
# female                        Dahlberg, Miss Gerda Ulrika    3rd  22.0
# female  Dyker, Mrs Adolf Fredrik (Anna Elizabeth Judit...    3rd  22.0
# female                             Hellstrom, Hilda Maria    3rd  22.0
# female                            Hirvonen, Mrs Alexander    3rd  22.0
# female                                   Kink, Miss Maria    3rd  22.0
# female                      Landegren, Miss Aurora Adelia    3rd  22.0
#
#            Sex  Survived  SexCode
# Sex
# female  female         1        1
# female  female         1        1
# female  female         1        1
# female  female         1        1
# female  female         0        1
# female  female         1        1
# female  female         0        1
# female  female         1        1
# female  female         1        1
# female  female         0        1
# female  female         1        1
# female  female         1        1
# female  female         1        1
# female  female         0        1
# female  female         1        1

# %%
df[(df['Sex'] == 'male') & (df['Age'] == 22) & (df['Survived'] == 0)]
# Out:
#                               Name PClass   Age   Sex  Survived  SexCode
# Sex
# male     Payne, Mr Vivian Ponsonby    1st  22.0  male         0        0
# male               Giles, Mr Ralph    2nd  22.0  male         0        0
# male  Smith (Schmidt), Mr Augustus    2nd  22.0  male         0        0
# male   Troupiansky, Mr Moses Aaron    2nd  22.0  male         0        0
# male           Waelens, Mr Achille    2nd  22.0  male         0        0
# male              Barton, Mr David    3rd  22.0  male         0        0
# male   Berglund, Mr Karl Ivar Sven    3rd  22.0  male         0        0
# male        Braund, Mr Owen Harris    3rd  22.0  male         0        0
# male        Brobek, Mr Karl Rudolf    3rd  22.0  male         0        0
# male               Davies, Mr Evan    3rd  22.0  male         0        0
# male           Gilinski, Mr Leslie    3rd  22.0  male         0        0
# male            Johansson, Mr Erik    3rd  22.0  male         0        0
# male      Karlsson, Mr Nils August    3rd  22.0  male         0        0
# male            Kiernan, Mr Philip    3rd  22.0  male         0        0
# male          Kilgannon, Mr Thomas    3rd  22.0  male         0        0
# male   Larsson-Rondberg, Mr Edvard    3rd  22.0  male         0        0
# male                Vonk, Mr Jenko    3rd  22.0  male         0        0
# male              Zenni, Mr Philip    3rd  22.0  male         0        0

# %%
df['Sex'].replace(['female','male'],['Woman','Man']).head(5)
# Out:
# Sex
# female    Woman
# female    Woman
# female    Woman
# female    Woman
# male        Man
# Name: Sex, dtype: object

# %%
df.rename(columns={'PClass': 'Passenger Class'}).head(5)
# Out:
#                               Name Passenger Class   Age     Sex  Survived  \
# Sex
# female  Bowerman, Miss Elsie Edith             1st  22.0  female         1
# female  Frolicher, Miss Marguerite             1st  22.0  female         1
# female        Gibson, Miss Dorothy             1st  22.0  female         1
# female  Ostby, Miss Helen Raghnild             1st  22.0  female         1
# male     Payne, Mr Vivian Ponsonby             1st  22.0    male         0
#
#         SexCode
# Sex
# female        1
# female        1
# female        1
# female        1
# male          0

# %%
df.replace([r"1st",r"2nd",r"3rd"], ['First','Second','Third'], regex=True).head(10)
# Out:
#                                                 Name  PClass   Age     Sex  \
# Sex
# female                    Bowerman, Miss Elsie Edith   First  22.0  female
# female                    Frolicher, Miss Marguerite   First  22.0  female
# female                          Gibson, Miss Dorothy   First  22.0  female
# female                    Ostby, Miss Helen Raghnild   First  22.0  female
# male                       Payne, Mr Vivian Ponsonby   First  22.0    male
# female                       Cook, Mrs Selena Rogers  Second  22.0  female
# female  del Carlo, Mrs Sebastiano (Argenia Genovese)  Second  22.0  female
# male                                 Giles, Mr Ralph  Second  22.0    male
# female          Karnes, Mrs J Frank (Claire Bennett)  Second  22.0  female
# female                  LaRoche, Mrs Joseph (Juliet)  Second  22.0  female
#
#         Survived  SexCode
# Sex
# female         1        1
# female         1        1
# female         1        1
# female         1        1
# male           0        0
# female         0        1
# female         1        1
# male           0        0
# female         0        1
# female         1        1

# %%
url = 'https://tinyurl.com/titanic-csv'

df = pd.read_csv(url)

# %%
print("Maximum: ", df['Age'].max())
print("Minimum: ", df['Age'].min())
print('Mean: ', df['Age'].mean())
print('Count: ', df['Age'].count())
# Out:
# ('Maximum: ', 71.0)
# ('Minimum: ', 0.17)
# ('Mean: ', 30.397989417989415)
# ('Count: ', 756)

# %%
data = df.copy()

# %%
data.shape
# Out:
# (1313, 6)

# %%
data.count()
# Out:
# Name        1313
# PClass      1313
# Age          756
# Sex         1313
# Survived    1313
# SexCode     1313
# dtype: int64

# %%
data['Sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data['Sex'].value_counts()
# Out:
# male      851
# female    462
# Name: Sex, dtype: int64

# %%
data['PClass'].value_counts()
# Out:
# 3rd    711
# 1st    322
# 2nd    279
# *        1
# Name: PClass, dtype: int64

# %%
data['PClass'].nunique()
# Out:
# 4

# %%
data[data['Age'].isnull()].head(5)
# Out:
#                             Name PClass  Age     Sex  Survived  SexCode
# 12  Aubert, Mrs Leontine Pauline    1st  NaN  female         1        1
# 13      Barkworth, Mr Algernon H    1st  NaN    male         1        0
# 14            Baumann, Mr John D    1st  NaN    male         0        0
# 29       Borebank, Mr John James    1st  NaN    male         0        0
# 32            Bradley, Mr George    1st  NaN    male         1        0

# %%
data.drop('SexCode', axis=1).head(5)
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
data[data['Sex'] != 'female'].head(5)
# Out:
#                                   Name PClass    Age   Sex  Survived  SexCode
# 2  Allison, Mr Hudson Joshua Creighton    1st  30.00  male         0        0
# 4        Allison, Master Hudson Trevor    1st   0.92  male         1        0
# 5                   Anderson, Mr Harry    1st  47.00  male         1        0
# 7               Andrews, Mr Thomas, jr    1st  39.00  male         0        0
# 9               Artagaveytia, Mr Ramon    1st  71.00  male         0        0

# %%
data.drop_duplicates().head(5)
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %%
data.drop_duplicates(subset=['Sex'])
# Out:
#                                   Name PClass   Age     Sex  Survived  SexCode
# 0         Allen, Miss Elisabeth Walton    1st  29.0  female         1        1
# 2  Allison, Mr Hudson Joshua Creighton    1st  30.0    male         0        0

# %%
data.drop_duplicates(subset=['Sex'], keep='last')
# Out:
#                      Name PClass   Age     Sex  Survived  SexCode
# 1307  Zabour, Miss Tamini    3rd   NaN  female         0        1
# 1312       Zimmerman, Leo    3rd  29.0    male         0        0

# %%
data.groupby('Sex').mean()
# Out:
#               Age  Survived  SexCode
# Sex
# female  29.396424  0.666667      1.0
# male    31.014338  0.166863      0.0

# %%
data.groupby(['Sex','Survived'])['Age'].mean()
# Out:
# Sex     Survived
# female  0           24.901408
#         1           30.867143
# male    0           32.320780
#         1           25.951875
# Name: Age, dtype: float64

# %%
for name in data['Name'][0:5]:
    print(name.upper())
# Out:
# ALLEN, MISS ELISABETH WALTON
# ALLISON, MISS HELEN LORAINE
# ALLISON, MR HUDSON JOSHUA CREIGHTON
# ALLISON, MRS HUDSON JC (BESSIE WALDO DANIELS)
# ALLISON, MASTER HUDSON TREVOR

# %%
[name for name in data['Name'][0:5]]
# Out:
# ['Allen, Miss Elisabeth Walton',
#  'Allison, Miss Helen Loraine',
#  'Allison, Mr Hudson Joshua Creighton',
#  'Allison, Mrs Hudson JC (Bessie Waldo Daniels)',
#  'Allison, Master Hudson Trevor']

# %%
def upperCase(x):
    return x.upper()

# %%
data["Name"].apply(upperCase)[0:5]
# Out:
# 0                     ALLEN, MISS ELISABETH WALTON
# 1                      ALLISON, MISS HELEN LORAINE
# 2              ALLISON, MR HUDSON JOSHUA CREIGHTON
# 3    ALLISON, MRS HUDSON JC (BESSIE WALDO DANIELS)
# 4                    ALLISON, MASTER HUDSON TREVOR
# Name: Name, dtype: object

# %%
data.groupby('Sex').apply(lambda x: x.count())
# Out:
#         Name  PClass  Age  Sex  Survived  SexCode
# Sex
# female   462     462  288  462       462      462
# male     851     851  468  851       851      851
